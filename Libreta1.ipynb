# %% [markdown]
# <a href="https://colab.research.google.com/github/3dgarxx3/Mineria_Datos/blob/main/Libreta1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mineria de datos

# %% [markdown]
# ## Primer parcial

# %% [markdown]
# ### Introduccion

# %% [markdown]
# #### Conceptos

# %% [markdown]
# Es el proceso de extraer informacion util a partir de una acumulacion de datos.

# %% [markdown]
# #### Ciencia de datos

# %% [markdown]
# Es un término que incluye muchas tecnologías de la información, tales como estadística, matemática y técnicas informáticas sofisticadas, aplicadas a los datos.

# %%
# La funcion help nos muestra la ayuda
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
# Otra forma de mostrar ayuda es utilizando ?
len?

# %%
# Ejemplo de ayuda en una lista
L = [1, 2, 3]
L.insert?

# %%
# Otro ejemplo de ayuda
L?

# %%
def square(a):
  """Return the square of a."""
  return a ** 2

# %%
square?

# %%
square??

# %%
len??

# %%
L.insert
# Out:
# <function list.insert(index, object, /)>
